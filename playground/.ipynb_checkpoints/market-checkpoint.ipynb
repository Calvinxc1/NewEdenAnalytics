# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector as mdb
import ujson as js
import torch as pt
import tqdm
import mysql.connector as mdb

sns.set()

from utils.market_parser import market_smooth
from utils.sql_pullers import get_types

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
pd.options.display.float_format = '{:,.2f}'.format

# %%
def mat_eff_calc(mat_quant, me_level):
    quant_actual = np.maximum(1, np.ceil(np.round(mat_quant * ((100 - me_level) / 100), 2))).astype(int)
    return quant_actual

# %%
with open('./utils/sql_calls.json') as file:
    sql = js.load(file)

mat_region_id = 10000043
sale_region_id = 10000052
#sale_region_id = 10000043

h = 14
markets = {}
prices = {}

market_start = '2019-01-01'

# %%
with open('./../settings/maria_login.json') as file:
    conn = mdb.connect(**js.load(file))

# %%
corp_bps = pd.read_sql(sql['corp']['bpos'], conn, index_col='bp_item_id')
corp_bps = corp_bps.loc[corp_bps[['bp_type_id', 'mat_eff', 'time_eff']].drop_duplicates().index]
corp_bps.index = corp_bps.index.astype(str)

# %%
corp_orders = pd.read_sql(sql['corp']['orders'], conn, index_col='order_id')

# %%
bp_data = {}
for key, script in sql['bp'].items():
    bp_data[key] = pd.read_sql(script.format(type_ids=','.join(corp_bps['bp_type_id'].astype(str))), conn)

# %%
invent = {
    'mats': {
        'quant': corp_bps.reset_index().merge(
            bp_data['mats'].loc[bp_data['mats']['act_id'] == 8],
            on='bp_type_id'
        )[['bp_item_id', 'bp_type_id', 'mat_eff', 'mat_type_id', 'mat_quant']].pivot(
            index='bp_item_id',
            columns='mat_type_id',
            values='mat_quant'
        ).fillna(0)
    }
}

# %%
markets['invent'] = market_smooth(mat_region_id, invent['mats']['quant'].columns, h, start_date=market_start)

prices[mat_region_id] = pd.DataFrame(
    [{
        'type_id': type_id,
        'avg_price': vals[h]['level'].iloc[-1]['avg_price'],
        'variance': vals[h]['var'].iloc[-1]['avg_price']
    } for type_id, vals in markets['invent'][mat_region_id].items()]
).set_index('type_id')

invent['mats']['price'] = pd.concat([
    (prices[mat_region_id]['avg_price'] * invent['mats']['quant']).sum(axis=1),
    (prices[mat_region_id]['variance'] * (invent['mats']['quant']**2)).sum(axis=1)
], axis=1)
invent['mats']['price'].columns = prices[mat_region_id].columns
# Out:
# /home/calvinxc1/conda/envs/analysis/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
invent['prods'] = corp_bps.reset_index().merge(
    bp_data['prods'].loc[bp_data['prods']['act_id'] == 8],
    on='bp_type_id'
)[['bp_item_id', 'bp_type_id', 'prod_type_id', 'prod_quant', 'prod_prob']]
invent['prods']['avg_price_run'] = invent['prods']['bp_item_id'].map(invent['mats']['price']['avg_price'])
invent['prods']['variance_run'] = invent['prods']['bp_item_id'].map(invent['mats']['price']['variance'])
invent['prods']['avg_price_unit'] = invent['prods']['avg_price_run'] / invent['prods'][['prod_quant', 'prod_prob']].product(axis=1)
invent['prods']['variance_unit'] = invent['prods']['variance_run'] * (invent['prods'][['prod_quant', 'prod_prob']].product(axis=1)**2)
invent['prods'].index = invent['prods']['bp_item_id'] + ':' + invent['prods']['prod_type_id'].astype(str)
invent['prods'].index.name = 'bp_item_id'
invent['prods'].drop(['bp_item_id', 'bp_type_id'], axis=1, inplace = True)

# %%
invent_bps = corp_bps.loc[invent['prods'].index.to_series().apply(lambda x: x.split(':')[0])]
invent_bps.index = invent['prods'].index
invent_bps['bp_type_id'] = invent['prods']['prod_type_id']
invent_bps['mat_eff'] = 2
invent_bps['time_eff'] = 4
corp_bps = corp_bps.append(invent_bps)
corp_bps.index.name = 'bp_item_id'
del invent_bps

# %%
for key, sql in sql['bp'].items():
    bp_data[key] = bp_data[key].append(
        pd.read_sql(sql.format(type_ids=','.join(invent['prods']['prod_type_id'].unique().astype(str))), conn),
        ignore_index=True
    ).drop_duplicates().reset_index(drop=True)

# %%
build = {
    'count': corp_bps.reset_index().merge(
        bp_data['mats'].loc[bp_data['mats']['act_id'] == 1],
        on='bp_type_id'
    )[['bp_item_id', 'bp_type_id', 'mat_eff', 'mat_type_id', 'mat_quant']]
}
build['count']['mat_actual'] = np.maximum(1, np.ceil(np.round(build['count']['mat_quant'] * ((100 - build['count']['mat_eff']) / 100), 2)))
build['count'] = build['count'].pivot(index='bp_item_id', columns='mat_type_id', values='mat_actual').fillna(0)

# %%
sub_prods = bp_data['prods'].loc[
    (bp_data['prods']['prod_type_id'].isin(build['count'].columns)) & (bp_data['prods']['act_id'] == 1)
][['bp_type_id', 'prod_type_id', 'prod_quant', 'prod_prob']].reset_index(drop=True)
sub_prods = sub_prods.merge(bp_data['mats'].loc[bp_data['mats']['act_id'] == 1, ['bp_type_id', 'mat_type_id', 'mat_quant']], on='bp_type_id')
sub_prods = corp_bps.reset_index()[['bp_item_id', 'bp_type_id', 'mat_eff']].merge(sub_prods, on='bp_type_id')
sub_prods['mat_actual'] = mat_eff_calc(sub_prods['mat_quant'], sub_prods['mat_eff'])
sub_prods['mat_unit'] = sub_prods['mat_actual'] / (sub_prods['prod_quant'] * sub_prods['prod_prob'])
sub_prods['bp_item_id.prod_type_id'] = sub_prods['bp_item_id'] + '.' + sub_prods['prod_type_id'].astype(str)
sub_prods = sub_prods.pivot(index='bp_item_id.prod_type_id', columns='mat_type_id', values='mat_unit').fillna(0)
sub_prods.index = pd.Series([int(col.split('.')[1]) for col in sub_prods.index], name='prod_type_id')

active = True
while active:
    build_mod = build['count'][sub_prods.index] @ sub_prods
    build['count'][sub_prods.index] = 0
    build['count'].loc[build_mod.index, build_mod.columns] += build_mod
    build['count'] = build['count'].loc[:, build['count'].sum(axis=0) > 0]
    
    sub_prods = bp_data['prods'].loc[
        (bp_data['prods']['prod_type_id'].isin(build['count'].columns)) & (bp_data['prods']['act_id'] == 1)
    ][['bp_type_id', 'prod_type_id', 'prod_quant', 'prod_prob']].reset_index(drop=True)
    sub_prods = sub_prods.merge(bp_data['mats'].loc[bp_data['mats']['act_id'] == 1, ['bp_type_id', 'mat_type_id', 'mat_quant']], on='bp_type_id')
    sub_prods = corp_bps.reset_index()[['bp_item_id', 'bp_type_id', 'mat_eff']].merge(sub_prods, on='bp_type_id')
    sub_prods['mat_actual'] = mat_eff_calc(sub_prods['mat_quant'], sub_prods['mat_eff'])
    sub_prods['mat_unit'] = sub_prods['mat_actual'] / (sub_prods['prod_quant'] * sub_prods['prod_prob'])
    sub_prods['bp_item_id.prod_type_id'] = sub_prods['bp_item_id'] + '.' + sub_prods['prod_type_id'].astype(str)
    sub_prods = sub_prods.pivot(index='bp_item_id.prod_type_id', columns='mat_type_id', values='mat_unit').fillna(0)
    sub_prods.index = pd.Series([int(col.split('.')[1]) for col in sub_prods.index], name='prod_type_id')
    
    if len(sub_prods) == 0: active = False

# %%
markets['build'] = market_smooth(mat_region_id, build['count'].columns, h, start_date=market_start)

prices[mat_region_id] = prices[mat_region_id].append(pd.DataFrame(
    [{
        'type_id': type_id,
        'avg_price': vals[h]['level'].iloc[-1]['avg_price'],
        'variance': vals[h]['var'].iloc[-1]['avg_price']
    } for type_id, vals in markets['build'][mat_region_id].items()]
).set_index('type_id')).drop_duplicates().sort_index()

# %%
build['price'] = pd.concat([
    (build['count'] * prices[mat_region_id]['avg_price']).sum(axis=1),
    ((build['count']**2) * prices[mat_region_id]['variance']).sum(axis=1)
], axis=1)
build['price'].columns = ['%s_run' % col for col in prices[mat_region_id].columns]

# %%
build['prods'] = corp_bps.reset_index().merge(
    bp_data['prods'].loc[bp_data['prods']['act_id'] == 1],
    on='bp_type_id'
)[['bp_item_id', 'prod_type_id', 'prod_quant', 'prod_prob']]
build['prods']['avg_price_run'] = build['prods']['bp_item_id'].map(build['price']['avg_price_run'])
build['prods']['variance_run'] = build['prods']['bp_item_id'].map(build['price']['variance_run'])
build['prods'].set_index('bp_item_id', inplace=True)

# %%
build['cost'] = build['prods'][['prod_type_id', 'prod_quant', 'prod_prob', 'avg_price_run', 'variance_run']].join(
    invent['prods'][['avg_price_unit', 'variance_unit']]
).fillna(0)
build['cost'].rename(columns={'avg_price_unit':'avg_price_invent', 'variance_unit':'variance_invent'}, inplace=True)

# %%
build['cost']['avg_price_unit'] = (
    build['cost']['avg_price_run'] + build['cost']['avg_price_invent']
) / (
    build['cost']['prod_quant'] * build['cost']['prod_prob']
)
build['cost']['variance_unit'] = (
    build['cost']['variance_run'] + build['cost']['variance_invent']
) / (
    (build['cost']['prod_quant'] * build['cost']['prod_prob'])**2
)

# %%
markets['sale'] = market_smooth(sale_region_id, build['cost']['prod_type_id'].unique(), h, start_date=market_start)

prices[sale_region_id] = pd.DataFrame(
    [{
        'type_id': type_id,
        'avg_price': vals[h]['level'].iloc[-1]['avg_price'],
        'variance': vals[h]['var'].iloc[-1]['avg_price']
    } for type_id, vals in markets['sale'][sale_region_id].items()]
).set_index('type_id')

# %%
build['cost']['avg_price_sale'] = build['cost']['prod_type_id'].map(prices[sale_region_id]['avg_price'])
build['cost']['variance_sale'] = build['cost']['prod_type_id'].map(prices[sale_region_id]['variance'])
build['cost']['avg_profit'] = build['cost']['avg_price_sale'] - build['cost']['avg_price_unit']
build['cost']['profit_ratio'] = build['cost']['avg_profit'] / build['cost']['avg_price_unit']
build['cost']['variance_profit'] = build['cost']['variance_sale'] + build['cost']['variance_unit']
build['cost']['stdev_profit'] = np.sqrt(build['cost']['variance_profit'])
build['cost']['z_profit'] = build['cost']['avg_profit'] / (np.sqrt(build['cost']['variance_sale']) + np.sqrt(build['cost']['variance_unit']))

# %%
types = get_types(build['cost']['prod_type_id'])
build['cost']['prod_type_name'] = build['cost']['prod_type_id'].map(types['type_name'])
build['cost']['prod_group_name'] = build['cost']['prod_type_id'].map(types['group_name'])
build['cost']['prod_cat_name'] = build['cost']['prod_type_id'].map(types['category_name'])

# %%
volume = pd.DataFrame(
    [{
        'type_id': type_id,
        'avg_volume': vals[h]['level'].iloc[-1]['volume'],
        'variance': vals[h]['var'].iloc[-1]['volume']
    } for type_id, vals in markets['sale'][sale_region_id].items()]
).set_index('type_id')

build['cost']['volume'] = build['cost']['prod_type_id'].map(volume['avg_volume'])
build['cost']['vol_var'] = build['cost']['prod_type_id'].map(volume['variance'])
build['cost']['avg_value'] = build['cost']['avg_profit'] * build['cost']['volume']
build['cost']['var_value'] = (
    build['cost']['variance_profit'] * build['cost']['vol_var']
) + (
    build['cost']['variance_profit'] * (build['cost']['volume']**2)
) + (
    (build['cost']['avg_profit']**2) * build['cost']['vol_var']
)
build['cost']['stdev_value'] = np.sqrt(build['cost']['var_value'])

# %%
build['cost']['active_order'] = build['cost']['prod_type_id'].isin(corp_orders['type_id'])

# %%
build['cost'].loc[
    ~build['cost']['active_order'],
    [
        'prod_cat_name', 'prod_group_name', 'prod_type_name', 'avg_price_unit',
        'avg_price_sale', 'avg_profit', 'profit_ratio', 'stdev_profit', 'volume',
        'avg_value'
    ]
].sort_values('avg_value', ascending=False).iloc[:50]
# Out:
#                     prod_cat_name                 prod_group_name  \
# bp_item_id
# 278129470                    Ship                      Battleship
# 1010832340145:33698          Ship              Expedition Frigate
# 443581437:30837            Module                        Salvager
# 885906076:11187              Ship                     Interceptor
# 567671432:2479              Drone                    Combat Drone
# 519249209:2421             Module        Missile Launcher Torpedo
# 1532766410:21639            Drone                    Combat Drone
# 1532765598:21641            Drone                    Combat Drone
# 470889849:2622             Charge         Advanced Cruise Missile
# 962734487:12105            Module                 Cloaking Device
# 1236757874:32048           Module                      Rig Drones
# 160106240                    Ship            Combat Battlecruiser
# 567946977:1336             Module             Reinforced Bulkhead
# 947618724:3505             Module               Capacitor Battery
# 434852424:3489             Module               Capacitor Battery
# 1650228580:28210            Drone                    Combat Drone
# 436328497:2554             Module     Shield Resistance Amplifier
# 149637864:2334             Module                  Survey Scanner
# 1552833534:26915           Module           Remote Armor Repairer
# 728500888:11808            Module                  Sensor Booster
# 1532780769:22292           Module        Ballistic Control system
# 922241650:24428            Module      Drone Control Range Module
# 1051212744:2437             Drone                    Combat Drone
# 470891536:24536            Charge         Advanced Cruise Missile
# 1051213588:2196             Drone                    Combat Drone
# 434850386:1080             Module                  Warp Scrambler
# 305164883:1542             Module         Power Diagnostic System
# 519238904:3541             Module               Armor Repair Unit
# 885907987:2467              Drone                    Combat Drone
# 984520418:30833            Module                     Data Miners
# 436325227:2540             Module     Shield Resistance Amplifier
# 567672053:2176              Drone                    Combat Drone
# 307289977:2411             Module          Missile Launcher Heavy
# 567474979:1095             Module                  Gyrostabilizer
# 922241605:24418            Module       Drone Navigation Computer
# 1098496437:16029           Module               Projectile Weapon
# 470890656:24538            Charge         Advanced Cruise Missile
# 712763151:25716            Module  Missile Launcher Heavy Assault
# 1010832340145:39583          Ship              Expedition Frigate
# 328370743:1237             Module       Overdrive Injector System
# 436309419:1249             Module             Capacitor Flux Coil
# 1621554729                   Ship                      Industrial
# 922241586:24439            Module          Drone Tracking Modules
# 984527220:18599            Charge                  Mining Crystal
# 1544516305:19740           Module         Missile Launcher Cruise
# 434849886:3245             Module                  Warp Scrambler
# 1552829105:11270           Module         Armor Plating Energized
# 1022269805825:31737        Module                      Rig Shield
# 1098355499:3155            Module                   Hybrid Weapon
# 922308957                  Module                  Mining Upgrade
#
#                                                  prod_type_name  \
# bp_item_id
# 278129470                                            Armageddon
# 1010832340145:33698                                    Prospect
# 443581437:30837                                     Salvager II
# 885906076:11187                                     Malediction
# 567671432:2479                                     Berserker II
# 519249209:2421                              Torpedo Launcher II
# 1532766410:21639                                       Vespa II
# 1532765598:21641                                    Valkyrie II
# 470889849:2622                      Inferno Fury Cruise Missile
# 962734487:12105                   Covert Ops Cloaking Device II
# 1236757874:32048               Medium Drone Mining Augmentor II
# 160106240                                                 Ferox
# 567946977:1336                          Reinforced Bulkheads II
# 947618724:3505                             Large Cap Battery II
# 434852424:3489                             Small Cap Battery II
# 1650228580:28210                                      Warden II
# 436328497:2554                             EM Ward Amplifier II
# 149637864:2334                                Survey Scanner II
# 1552833534:26915                 Large Remote Armor Repairer II
# 728500888:11808                               Sensor Booster II
# 1532780769:22292                    Ballistic Control System II
# 922241650:24428                         Drone Link Augmentor II
# 1051212744:2437                                         Wasp II
# 470891536:24536                     Mjolnir Fury Cruise Missile
# 1051213588:2196                                      Praetor II
# 434850386:1080                                Warp Scrambler II
# 305164883:1542                       Power Diagnostic System II
# 519238904:3541                          Large Armor Repairer II
# 885907987:2467                                        Hornet II
# 984520418:30833                               Relic Analyzer II
# 436325227:2540                 Thermal Dissipation Amplifier II
# 567672053:2176                                   Infiltrator II
# 307289977:2411                        Heavy Missile Launcher II
# 567474979:1095                                Gyrostabilizer II
# 922241605:24418                    Drone Navigation Computer II
# 1098496437:16029                      800mm Repeating Cannon II
# 470890656:24538                   Nova Precision Cruise Missile
# 712763151:25716               Heavy Assault Missile Launcher II
# 1010832340145:39583                                   Endurance
# 328370743:1237                     Overdrive Injector System II
# 436309419:1249                           Capacitor Flux Coil II
# 1621554729                                        Iteron Mark V
# 922241586:24439                Omnidirectional Tracking Link II
# 984527220:18599                        Gneiss Mining Crystal II
# 1544516305:19740                     Cruise Missile Launcher II
# 434849886:3245                                Warp Disruptor II
# 1552829105:11270            Energized Adaptive Nano Membrane II
# 1022269805825:31737  Medium Anti-Explosive Screen Reinforcer II
# 1098355499:3155                           Ion Blaster Cannon II
# 922308957                                Mining Laser Upgrade I
#
#                      avg_price_unit  avg_price_sale    avg_profit  \
# bp_item_id
# 278129470            131,172,287.08  162,002,610.26 30,830,323.18
# 1010832340145:33698   23,548,894.63   36,565,440.89 13,016,546.26
# 443581437:30837          965,027.80    1,610,962.36    645,934.56
# 885906076:11187       29,574,001.59   36,297,053.06  6,723,051.47
# 567671432:2479         1,429,674.07    2,269,548.55    839,874.48
# 519249209:2421         4,902,509.30    6,998,687.66  2,096,178.36
# 1532766410:21639         731,787.79      940,969.82    209,182.03
# 1532765598:21641         730,758.84    1,112,110.67    381,351.83
# 470889849:2622               460.52        1,020.14        559.63
# 962734487:12105        5,241,781.46    7,481,659.93  2,239,878.47
# 1236757874:32048      22,479,666.04   32,833,315.04 10,353,649.00
# 160106240             31,529,694.11   33,630,508.45  2,100,814.34
# 567946977:1336           185,564.46      838,079.45    652,514.99
# 947618724:3505         1,795,400.96    3,089,841.48  1,294,440.52
# 434852424:3489           613,901.10    1,533,397.75    919,496.64
# 1650228580:28210       1,254,620.93    1,546,879.81    292,258.88
# 436328497:2554           708,074.25    1,225,209.93    517,135.69
# 149637864:2334           679,482.99    1,744,421.44  1,064,938.45
# 1552833534:26915       1,907,880.23    6,846,504.39  4,938,624.16
# 728500888:11808        1,129,066.48    2,776,093.89  1,647,027.40
# 1532780769:22292       1,108,359.76    1,935,330.27    826,970.51
# 922241650:24428          807,979.76    1,595,921.53    787,941.77
# 1051212744:2437        1,436,603.24    2,250,821.87    814,218.63
# 470891536:24536              463.87          722.26        258.39
# 1051213588:2196        1,462,169.39    2,197,849.31    735,679.93
# 434850386:1080         1,501,663.35    2,213,157.28    711,493.92
# 305164883:1542           881,398.07    1,256,326.14    374,928.07
# 519238904:3541         1,951,085.69    4,360,185.85  2,409,100.16
# 885907987:2467           283,220.24      368,846.71     85,626.47
# 984520418:30833        1,052,085.78    1,842,276.82    790,191.04
# 436325227:2540           698,488.99    1,894,739.84  1,196,250.85
# 567672053:2176           735,267.41    1,277,405.57    542,138.16
# 307289977:2411         1,047,402.61    2,167,795.79  1,120,393.18
# 567474979:1095           993,135.14    1,927,640.54    934,505.39
# 922241605:24418          851,391.23    1,609,767.08    758,375.86
# 1098496437:16029       2,841,993.07    6,274,664.73  3,432,671.66
# 470890656:24538              459.30          813.21        353.91
# 712763151:25716        1,046,813.19    1,667,625.18    620,812.00
# 1010832340145:39583   23,688,061.52   37,938,112.60 14,250,051.08
# 328370743:1237           431,101.27    1,106,243.32    675,142.06
# 436309419:1249           584,708.09    2,528,405.99  1,943,697.90
# 1621554729               909,433.12    1,286,725.67    377,292.54
# 922241586:24439          717,504.85    1,332,360.95    614,856.10
# 984527220:18599          475,701.30    1,196,498.84    720,797.54
# 1544516305:19740       2,540,391.89    4,023,836.81  1,483,444.92
# 434849886:3245         1,254,004.42    2,153,190.10    899,185.68
# 1552829105:11270         570,596.96      912,085.79    341,488.83
# 1022269805825:31737    2,712,925.60   15,000,000.00 12,287,074.40
# 1098355499:3155        3,702,262.73    6,500,000.00  2,797,737.27
# 922308957                 18,514.95       30,498.12     11,983.17
#
#                      profit_ratio  stdev_profit   volume    avg_value
# bp_item_id
# 278129470                    0.24 11,266,268.91     0.17 5,311,890.68
# 1010832340145:33698          0.55  2,765,029.65     0.18 2,402,245.88
# 443581437:30837              0.67    171,493.33     2.27 1,465,835.92
# 885906076:11187              0.23  3,905,179.76     0.19 1,262,060.22
# 567671432:2479               0.59    188,045.18     1.33 1,114,994.67
# 519249209:2421               0.43    195,357.28     0.39   825,609.49
# 1532766410:21639             0.29    483,358.46     3.61   754,314.37
# 1532765598:21641             0.52    521,376.40     1.88   717,856.82
# 470889849:2622               1.22        638.16 1,239.07   693,415.55
# 962734487:12105              0.43    399,932.59     0.29   646,104.93
# 1236757874:32048             0.46    689,729.72     0.06   572,841.91
# 160106240                    0.07  3,446,158.51     0.26   555,696.50
# 567946977:1336               3.52    521,180.77     0.83   542,927.60
# 947618724:3505               0.72    299,549.99     0.41   533,617.51
# 434852424:3489               1.50     61,790.32     0.56   513,116.57
# 1650228580:28210             0.23    305,402.16     1.69   495,013.99
# 436328497:2554               0.73    160,832.49     0.92   473,501.73
# 149637864:2334               1.57    259,414.02     0.43   461,732.16
# 1552833534:26915             2.59  1,280,979.56     0.09   449,100.04
# 728500888:11808              1.46    622,619.56     0.27   441,191.67
# 1532780769:22292             0.75    630,681.34     0.52   429,963.09
# 922241650:24428              0.98    651,144.50     0.53   419,603.86
# 1051212744:2437              0.57    184,641.23     0.51   415,115.02
# 470891536:24536              0.56        128.97 1,575.81   407,169.36
# 1051213588:2196              0.50    229,898.04     0.53   391,153.62
# 434850386:1080               0.47    197,100.97     0.50   355,018.94
# 305164883:1542               0.43    572,005.42     0.89   333,674.16
# 519238904:3541               1.23    923,782.42     0.13   304,661.49
# 885907987:2467               0.30    193,092.00     3.47   296,730.89
# 984520418:30833              0.75    421,624.30     0.37   294,495.81
# 436325227:2540               1.71    247,364.14     0.23   274,774.69
# 567672053:2176               0.74    200,188.00     0.49   267,088.90
# 307289977:2411               1.07    485,644.10     0.24   264,409.08
# 567474979:1095               0.94  1,110,760.47     0.28   262,224.08
# 922241605:24418              0.89    173,201.09     0.34   258,090.32
# 1098496437:16029             1.21    251,171.77     0.07   246,615.56
# 470890656:24538              0.77        272.58   695.82   246,257.26
# 712763151:25716              0.59    381,922.88     0.38   233,828.45
# 1010832340145:39583          0.60  2,829,013.33     0.02   229,793.36
# 328370743:1237               1.57    324,096.03     0.34   228,241.41
# 436309419:1249               3.32     72,844.10     0.12   228,045.81
# 1621554729                   0.41    107,968.80     0.58   220,605.38
# 922241586:24439              0.86    157,036.18     0.36   219,238.25
# 984527220:18599              1.52    191,034.56     0.28   199,192.06
# 1544516305:19740             0.58    275,114.38     0.13   189,041.93
# 434849886:3245               0.72    612,046.46     0.19   168,070.57
# 1552829105:11270             0.60    354,786.76     0.45   153,363.67
# 1022269805825:31737          4.53    235,079.48     0.01   149,325.42
# 1098355499:3155              0.76    137,981.39     0.05   141,376.22
# 922308957                    0.65     14,869.03    11.13   133,332.92

# %%
with open('./../settings/maria_login.json') as file:
    conn = mdb.connect(**js.load(file))

with open('./utils/sql.json') as file:
    undercuts = pd.read_sql(js.load(file)['undercuts'], conn, index_col = 'order_id')
undercuts['market_volume_sum'] = undercuts['market_volume_sum'].astype(int)
types = types.append(get_types([type_id for type_id in undercuts['type_id'].unique() if type_id not in types.index])).sort_index()
undercuts.insert(
    undercuts.columns.get_loc('type_id') + 1,
    'type_name',
    undercuts['type_id'].map(types['type_name'])
)

conn.close()

thresh = 0.1

mask = undercuts['volume'] * thresh <= undercuts['market_volume_sum']

print(undercuts.loc[mask].shape)
undercuts.loc[mask].sort_values('type_name', ascending=True).iloc[:50]
# Out:
# (1, 9)
#             type_id type_name  region_id         price  volume  \
# order_id
# 5510934373    24698     Drake   10000052 37,750,000.00       3
#
#             market_order_count  market_price_min  market_volume_sum  \
# order_id
# 5510934373                   1     37,500,000.00                  1
#
#             market_volume_max
# order_id
# 5510934373                  1

# %%
print(undercuts.loc[~mask].shape)
undercuts.loc[~mask].sort_values('type_name', ascending=True).iloc[:50]
# Out:
# (63, 9)
#             type_id                      type_name  region_id        price  \
# order_id
# 5483836089    12344                200mm Railgun I   10000052    95,000.00
# 5504398645      493     720mm Howitzer Artillery I   10000052   400,000.00
# 5483836091      561            75mm Gatling Rail I   10000052    17,500.00
# 5482099146    42832        Armor Energizing Charge   10000052       600.00
# 5503605315      608                          Atron   10000052   245,000.00
# 5482099152     3554                Cap Booster 100   10000052       750.00
# 5482099153    11285                Cap Booster 200   10000052    21,750.00
# 5484589981      194              Carbonized Lead L   10000052        75.00
# 5479289549      178              Carbonized Lead S   10000052        18.75
# 5488937812    12814                Conflagration M   10000052   225,000.00
# 5507247028     2161                      Crucifier   10000052   297,500.00
# 5484589983      197             Depleted Uranium L   10000052        50.00
# 5479289551      181             Depleted Uranium S   10000052        15.00
# 5501011755      456   Focused Medium Pulse Laser I   10000052   100,000.00
# 5495545784      199                       Fusion L   10000052       190.00
# 5495544416    18602   Hemorphite Mining Crystal II   10000052   425,000.00
# 5499717716     2454                    Hobgoblin I   10000052     2,500.00
# 5496665892      204         Inferno Cruise Missile   10000052       165.00
# 5482099179     2510                Inferno Torpedo   10000052       650.00
# 5484589987      233               Iridium Charge L   10000052        35.00
# 5479289557      225               Iridium Charge M   10000052        42.50
# 5484589988      231                  Iron Charge L   10000052        25.00
# 5482099182    18050        Jaspet Mining Crystal I   10000052    60,000.00
# 5504398648     3977       Large Proton Smartbomb I   10000052   875,000.00
# 5484589989      234                  Lead Charge L   10000052        70.00
# 5479289561      226                  Lead Charge M   10000052        50.00
# 5479289562      218                  Lead Charge S   10000052         8.50
# 5482099184    23711  Light Armor Maintenance Bot I   10000052     8,750.00
# 5499717717      564        Light Neutron Blaster I   10000052    42,500.00
# 5496665897      463              Mega Beam Laser I   10000052 2,000,000.00
# 5496665893      202         Mjolnir Cruise Missile   10000052       275.00
# 5482099194      262               Multifrequency L   10000052    38,750.00
# 5499717723      246               Multifrequency S   10000052    17,500.00
# 5504398654      573       Neutron Blaster Cannon I   10000052 1,000,000.00
# 5498526679      205            Nova Cruise Missile   10000052       325.00
# 5501011757     2508                   Nova Torpedo   10000052       875.00
# 5484589990      195                      Nuclear L   10000052        85.00
# 5479289566      179                      Nuclear S   10000052        20.00
# 5484589992      237             Plutonium Charge L   10000052       125.00
# 5479289569      229             Plutonium Charge M   10000052       150.00
# 5479289570      221             Plutonium Charge S   10000052         9.50
# 5505671938      196                       Proton L   10000052        42.50
# 5479289572      180                       Proton S   10000052        15.00
# 5482099204    42833            Rapid Repair Charge   10000052       700.00
# 5488937827    12563                       Scorch S   10000052    75,000.00
# 5482099208    18062      Scordite Mining Crystal I   10000052    13,750.00
# 5505668102    20307  Scourge Heavy Assault Missile   10000052        65.00
# 5496665894      267                Scourge Torpedo   10000052       487.50
# 5482099211     1254             Shield Flux Coil I   10000052    30,000.00
# 5495545791    24348           Small Tractor Beam I   10000052 1,250,000.00
#
#             volume  market_order_count  market_price_min  market_volume_sum  \
# order_id
# 5483836089     100                   1         86,000.00                  4
# 5504398645     100                   1        360,000.00                  1
# 5483836091      92                   1          2,000.00                  3
# 5482099146    6900                   1            540.00                470
# 5503605315      25                   1        200,000.00                  1
# 5482099152    4652                   1            680.00                 50
# 5482099153    2263                   1         19,000.00                152
# 5484589981  100000                   1             69.00               4000
# 5479289549   75000                   1             17.00               2800
# 5488937812      90                   2        199,999.00                  7
# 5507247028      25                   1        250,000.00                  1
# 5484589983  100000                   2             45.00               8000
# 5479289551  100000                   1             12.00               5000
# 5501011755     100                   1         90,000.00                  4
# 5495545784  137000                   1            170.00               3000
# 5495544416      43                   1        400,000.00                  2
# 5499717716     446                   1          2,399.00                  2
# 5496665892   98000                   1            150.00               4000
# 5482099179   43500                   2            585.00               3400
# 5484589987  100000                   2             32.00               5786
# 5479289557  100000                   1             38.00               1900
# 5484589988  100000                   1             23.00               3804
# 5482099182     169                   1         54,000.00                  1
# 5504398648     100                   1        800,000.00                  6
# 5484589989  100000                   1             63.00                 27
# 5479289561   97000                   1             45.00               1800
# 5479289562   95137                   1              8.00               4500
# 5482099184     487                   1          8,500.00                 20
# 5499717717     100                   1         38,000.00                  4
# 5496665897     100                   1      1,900,000.00                  6
# 5496665893  100000                   1            250.00               2000
# 5482099194      38                   1         37,000.00                  2
# 5499717723     100                   1          4,400.00                  1
# 5504398654     100                   1        900,000.00                  1
# 5498526679  100000                   1            160.00               5000
# 5501011757  100000                   1            800.00               6300
# 5484589990  100000                   1             78.00               2000
# 5479289566  100000                   1              6.00               3000
# 5484589992  100000                   1             75.00               9840
# 5479289569   96000                   1            135.00               5100
# 5479289570  100000                   1              8.00               2200
# 5505671938  140000                   2             38.00               5300
# 5479289572  100000                   1              9.00                100
# 5482099204   19699                   1            630.00               1000
# 5488937827     120                   1         70,000.00                  8
# 5482099208     173                   1         13,749.00                  2
# 5505668102  100000                   1             60.00               6000
# 5496665894  100000                   1            280.00               2300
# 5482099211      14                   1         27,000.00                  1
# 5495545791     169                   1      1,000,000.00                  1
#
#             market_volume_max
# order_id
# 5483836089                  4
# 5504398645                  1
# 5483836091                  3
# 5482099146                470
# 5503605315                  1
# 5482099152                 50
# 5482099153                152
# 5484589981               4000
# 5479289549               2800
# 5488937812                  5
# 5507247028                  1
# 5484589983               5000
# 5479289551               5000
# 5501011755                  4
# 5495545784               3000
# 5495544416                  2
# 5499717716                  2
# 5496665892               4000
# 5482099179               2400
# 5484589987               5286
# 5479289557               1900
# 5484589988               3804
# 5482099182                  1
# 5504398648                  6
# 5484589989                 27
# 5479289561               1800
# 5479289562               4500
# 5482099184                 20
# 5499717717                  4
# 5496665897                  6
# 5496665893               2000
# 5482099194                  2
# 5499717723                  1
# 5504398654                  1
# 5498526679               5000
# 5501011757               6300
# 5484589990               2000
# 5479289566               3000
# 5484589992               9840
# 5479289569               5100
# 5479289570               2200
# 5505671938               3100
# 5479289572                100
# 5482099204               1000
# 5488937827                  8
# 5482099208                  2
# 5505668102               6000
# 5496665894               2300
# 5482099211                  1
# 5495545791                  1
